# %%
# Import Dependencies
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
# Load csv into DataFrame
df_earthquakes = pd.read_csv("Resources/eq_data.csv")

# %%
# Connect to/Create database
conn = sqlite3.connect("Resources/earthquakes.sqlite")

# %%
# Write the dataframe to the earthquakes database into eq_data table
df_earthquakes.to_sql("eq_data", conn, if_exists="replace", index=False)
# Out:
# 7449

# %%
# Load SELECT data into DataFrame
df_magnitude_by_magType = pd.read_sql_query("SELECT mag, magType FROM eq_data", conn)

# %%
# Calculate the mean magnitude for each magType
df_grouped = df_magnitude_by_magType.groupby("magType").mean()
df_grouped
# Out:
#               mag
# magType
# Ml       3.600000
# ma       3.000000
# mb       3.650000
# mc       3.114615
# md       3.159779
# mh       3.415385
# ml       3.324466
# mlr      3.804760
# mw       3.828904
# mwr      3.950000

# %%
# Plot the mean magnitude by magnitude type
df_grouped.plot(kind="bar")

# Label x and y axis
plt.xlabel("Magnitude Type")
plt.ylabel("Mean Magnitude")
plt.legend(["Average Magnitude by Magnitude Type"])

# Show the plot
plt.show()

# %%
# Load SELECT data into DataFrame
df_magnitude_by_time = pd.read_sql_query("SELECT time, mag FROM eq_data", conn)
df_magnitude_by_time
# Out:
#                           time   mag
# 0     2022-12-31T12:12:26.650Z  4.14
# 1     2022-12-31T11:41:09.460Z  3.47
# 2     2022-12-22T02:22:50.250Z  3.34
# 3     2022-12-20T15:30:01.280Z  3.01
# 4     2022-12-17T11:39:42.860Z  3.57
# ...                        ...   ...
# 7444  2000-01-06T21:38:10.940Z  3.85
# 7445  2000-01-03T21:59:31.780Z  3.49
# 7446  2000-01-02T17:58:32.820Z  3.14
# 7447  2000-01-02T15:49:40.650Z  3.11
# 7448  2000-01-01T03:58:39.500Z  3.04
#
# [7449 rows x 2 columns]

# %%
# Create a new dataframe with the converted date column
df_converted_mag_by_year = df_magnitude_by_time.copy()
df_converted_mag_by_year['year'] = pd.to_datetime(df_converted_mag_by_year['time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.year
df_converted_mag_by_year
# Out:
#                           time   mag  year
# 0     2022-12-31T12:12:26.650Z  4.14  2022
# 1     2022-12-31T11:41:09.460Z  3.47  2022
# 2     2022-12-22T02:22:50.250Z  3.34  2022
# 3     2022-12-20T15:30:01.280Z  3.01  2022
# 4     2022-12-17T11:39:42.860Z  3.57  2022
# ...                        ...   ...   ...
# 7444  2000-01-06T21:38:10.940Z  3.85  2000
# 7445  2000-01-03T21:59:31.780Z  3.49  2000
# 7446  2000-01-02T17:58:32.820Z  3.14  2000
# 7447  2000-01-02T15:49:40.650Z  3.11  2000
# 7448  2000-01-01T03:58:39.500Z  3.04  2000
#
# [7449 rows x 3 columns]

# %%
# Data types
check_dt = df_converted_mag_by_year.dtypes
print(check_dt)
# Out:
# time     object
# mag     float64
# year      int64
# dtype: object

# %%
df_mag_year = pd.DataFrame(df_converted_mag_by_year.groupby(["year"])["mag"].mean())
df_mag_year
# Out:
#            mag
# year
# 2000  3.357956
# 2001  3.344212
# 2002  3.339188
# 2003  3.414804
# 2004  3.404423
# 2005  3.438697
# 2006  3.392437
# 2007  3.413061
# 2008  3.413532
# 2009  3.471581
# 2010  3.422738
# 2011  3.400609
# 2012  3.490625
# 2013  3.409360
# 2014  3.389550
# 2015  3.386856
# 2016  3.417091
# 2017  3.367705
# 2018  3.417756
# 2019  3.454082
# 2020  3.455385
# 2021  3.439403
# 2022  3.415957

# %%
# Plot the mean magnitude by magnitude type
df_mag_year.plot(kind="bar")

# Label x and y axis
plt.xlabel("Year")
plt.ylabel("Mean Magnitude")
plt.yticks([0.0,0.5,1.0,1.5,2.0,2.5,3.0,3.5,4.0])
plt.legend(["Average Magnitude by Year"])

# Show the plot
plt.show()

# %%
df_mag_count = pd.DataFrame(df_converted_mag_by_year.groupby(["year"])["mag"].count())
df_mag_count
# Out:
#        mag
# year
# 2000   318
# 2001   311
# 2002   197
# 2003   408
# 2004   364
# 2005   261
# 2006   197
# 2007   196
# 2008   201
# 2009   253
# 2010   745
# 2011   197
# 2012   224
# 2013   203
# 2014   333
# 2015   264
# 2016   220
# 2017   183
# 2018   156
# 2019  1323
# 2020   390
# 2021   317
# 2022   188

# %%
# Plot the count of magnitude 3.0 tremor by year
df_mag_count.plot(kind="bar")

# Label x and y axis
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend(["Earthquake Count by Year > 3.0"])

# Show the plot
plt.show()

# %%
# Need to filter only California and convert back to JSON

# %%
# add a column for if text includes California or CA to include in dataframe
df_earthquakes['in_ca']=df_earthquakes['place'].str.contains('CA|California')
#filtered only true in in_ca column
ca_df=df_earthquakes.loc[df_earthquakes['in_ca']==True]
ca_df
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2022-12-31T12:12:26.650Z  33.397500 -116.393333   3.880  4.14      mw
# 1     2022-12-31T11:41:09.460Z  34.355667 -116.921833   4.730  3.47      mw
# 2     2022-12-22T02:22:50.250Z  37.620167 -122.025000   3.820  3.34      mw
# 3     2022-12-20T15:30:01.280Z  40.565667 -123.976667  20.100  3.01      ml
# 4     2022-12-17T11:39:42.860Z  37.918167 -122.304000   5.480  3.57      mw
# ...                        ...        ...         ...     ...   ...     ...
# 7444  2000-01-06T21:38:10.940Z  38.844000 -122.825667   1.500  3.85      mw
# 7445  2000-01-03T21:59:31.780Z  34.101000 -117.008000   2.269  3.49      ml
# 7446  2000-01-02T17:58:32.820Z  34.309000 -116.072000   0.801  3.14      ml
# 7447  2000-01-02T15:49:40.650Z  38.038333 -118.696000  -0.903  3.11      md
# 7448  2000-01-01T03:58:39.500Z  34.801000 -116.287000   5.414  3.04      ml
#
#         nst    gap     dmin    rms  ...                           place  \
# 0     132.0   16.0  0.07391  0.190  ...   16km N of Borrego Springs, CA
# 1     121.0   25.0  0.07845  0.150  ...  11km SSE of Lucerne Valley, CA
# 2     141.0   16.0      NaN  0.160  ...         3km N of Union City, CA
# 3      37.0   46.0  0.07691  0.140  ...        10km E of Hydesville, CA
# 4     170.0   19.0  0.01598  0.150  ...       1km ENE of El Cerrito, CA
# ...     ...    ...      ...    ...  ...                             ...
# 7444   56.0   31.0  0.04054  0.070  ...    9 km WNW of Cobb, California
# 7445    0.0   22.4      NaN  0.192  ...          8km NNE of Yucaipa, CA
# 7446    0.0   65.5      NaN  0.172  ...  19km N of Twentynine Palms, CA
# 7447   51.0  107.0  0.22520  0.060  ...  31 km NW of Benton, California
# 7448    0.0   48.3      NaN  0.163  ...           15km NW of Ludlow, CA
#
#             type horizontalError depthError magError  magNst    status  \
# 0     earthquake            0.10      0.380      NaN     6.0  reviewed
# 1     earthquake            0.09      0.410      NaN     4.0  reviewed
# 2     earthquake            0.10      0.170      NaN     3.0  reviewed
# 3     earthquake            0.22      0.340    0.274    22.0  reviewed
# 4     earthquake            0.10      0.170      NaN     4.0  reviewed
# ...          ...             ...        ...      ...     ...       ...
# 7444  earthquake            0.13      0.430      NaN     5.0  reviewed
# 7445  earthquake             NaN      0.122      NaN   221.0  reviewed
# 7446  earthquake             NaN      0.252      NaN   178.0  reviewed
# 7447  earthquake            0.20      6.580    0.180    73.0  reviewed
# 7448  earthquake             NaN      0.641      NaN   187.0  reviewed
#
#       locationSource  magSource in_ca
# 0                 ci         ci  True
# 1                 ci         ci  True
# 2                 nc         nc  True
# 3                 nc         nc  True
# 4                 nc         nc  True
# ...              ...        ...   ...
# 7444              nc         nc  True
# 7445              ci         ci  True
# 7446              ci         ci  True
# 7447              nc         nc  True
# 7448              ci         ci  True
#
# [7112 rows x 23 columns]

# %%
# add the year coulumn to ease the use in JavaScript
ca_df['year'] = pd.to_datetime(df_converted_mag_by_year['time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.year
ca_df.head()
# Out:
# /var/folders/wv/h5pdqs5n7nsg_yqxw3ycpkp40000gp/T/ipykernel_1424/3566571489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_df['year'] = pd.to_datetime(df_converted_mag_by_year['time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.year
#                        time   latitude   longitude  depth   mag magType  \
# 0  2022-12-31T12:12:26.650Z  33.397500 -116.393333   3.88  4.14      mw
# 1  2022-12-31T11:41:09.460Z  34.355667 -116.921833   4.73  3.47      mw
# 2  2022-12-22T02:22:50.250Z  37.620167 -122.025000   3.82  3.34      mw
# 3  2022-12-20T15:30:01.280Z  40.565667 -123.976667  20.10  3.01      ml
# 4  2022-12-17T11:39:42.860Z  37.918167 -122.304000   5.48  3.57      mw
#
#      nst   gap     dmin   rms  ...        type horizontalError depthError  \
# 0  132.0  16.0  0.07391  0.19  ...  earthquake            0.10       0.38
# 1  121.0  25.0  0.07845  0.15  ...  earthquake            0.09       0.41
# 2  141.0  16.0      NaN  0.16  ...  earthquake            0.10       0.17
# 3   37.0  46.0  0.07691  0.14  ...  earthquake            0.22       0.34
# 4  170.0  19.0  0.01598  0.15  ...  earthquake            0.10       0.17
#
#   magError magNst    status  locationSource  magSource  in_ca  year
# 0      NaN    6.0  reviewed              ci         ci   True  2022
# 1      NaN    4.0  reviewed              ci         ci   True  2022
# 2      NaN    3.0  reviewed              nc         nc   True  2022
# 3    0.274   22.0  reviewed              nc         nc   True  2022
# 4      NaN    4.0  reviewed              nc         nc   True  2022
#
# [5 rows x 24 columns]

# %%
#Convert into a JSON
ca_eq_json = ca_df.to_json("Resources/ca_eq_data.json")

# %%
#final result
ca_eq_json
# Out:
# '{"time":{"0":"2022-12-31T12:12:26.650Z","1":"2022-12-31T11:41:09.460Z","2":"2022-12-22T02:22:50.250Z","3":"2022-12-20T15:30:01.280Z","4":"2022-12-17T11:39:42.860Z","5":"2022-12-13T12:31:28.820Z","6":"2022-12-08T16:48:47.865Z","7":"2022-12-08T02:46:32.300Z","8":"2022-12-07T14:13:22.690Z","9":"2022-12-06T08:43:21.532Z","10":"2022-12-06T00:10:37.510Z","11":"2022-12-05T23:13:16.710Z","12":"2022-12-04T06:53:48.761Z","13":"2022-12-02T12:21:48.910Z","14":"2022-12-01T15:28:29.660Z","15":"2022-11-24T07:20:54.950Z","16":"2022-11-12T13:11:22.400Z","17":"2022-11-11T11:16:19.920Z","18":"2022-11-07T19:41:35.350Z","19":"2022-11-07T02:01:27.780Z","20":"2022-11-04T20:26:32.930Z","21":"2022-10-31T04:52:58.560Z","22":"2022-10-26T06:24:19.660Z","23":"2022-10-25T22:08:37.200Z","24":"2022-10-25T18:42:02.710Z","25":"2022-10-23T09:24:58.150Z","26":"2022-10-20T07:55:16.770Z","27":"2022-10-20T00:02:34.810Z","28":"2022-10-19T23:59:50.050Z","29":"2022-10-19T23:59:04.760Z","30":"2022-10-15T17:30:41.780Z","31":"2022-10-12T12:54:07.000Z","32":"2022-10-12T00:28:36.750Z","33":"2022-10-09T21:48:21.120Z","34":"2022-10-07T22:45:05.470Z","35":"2022-10-05T04:51:30.350Z","36":"2022-10-03T16:08:09.970Z","38":"2022-10-03T08:24:33.660Z","39":"2022-09-30T11:50:11.750Z","40":"2022-09-28T17:02:02.090Z","41":"2022-09-27T13:02:57.910Z","42":"2022-09-27T08:03:39.320Z","43":"2022-09-23T06:58:34.290Z","44":"2022-09-21T10:50:48.980Z","45":"2022-09-20T18:34:41.320Z","46":"2022-09-20T14:03:08.070Z","47":"2022-09-19T04:47:18.910Z","48":"2022-09-18T09:13:21.970Z","49":"2022-09-18T06:55:48.060Z","50":"2022-09-16T16:12:42.850Z","51":"2022-09-15T20:07:05.390Z","52":"2022-09-14T01:40:20.420Z","53":"2022-09-14T01:39:38.730Z","54":"2022-09-13T22:44:25.840Z","55":"2022-09-12T20:09:09.110Z","56":"2022-09-11T06:55:21.990Z","57":"2022-09-06T11:55:24.410Z","58":"2022-09-04T22:55:15.620Z","59":"2022-09-04T18:57:55.730Z","60":"2022-09-03T17:04:55.810Z","61":"2022-09-01T15:21:20.033Z","62":"2022-09-01T13:36:22.150Z","63":"2022-08-28T22:48:03.720Z","64":"2022-08-27T19:42:52.740Z","65":"2022-08-25T07:32:51.460Z","66":"2022-08-17T00:53:01.240Z","67":"2022-08-13T12:33:35.760Z","68":"2022-08-13T07:25:36.240Z","69":"2022-08-12T03:37:05.020Z","70":"2022-08-11T17:12:57.710Z","71":"2022-08-09T00:33:28.590Z","72":"2022-08-08T20:44:14.110Z","73":"2022-08-08T02:38:51.560Z","74":"2022-08-03T18:45:00.270Z","75":"2022-07-23T02:47:13.330Z","76":"2022-07-23T01:41:04.680Z","77":"2022-07-22T00:11:28.750Z","78":"2022-07-19T17:00:16.920Z","79":"2022-07-18T17:07:58.290Z","80":"2022-07-17T18:18:39.190Z","81":"2022-07-17T15:44:26.540Z","82":"2022-07-17T11:34:47.530Z","83":"2022-07-17T10:41:43.560Z","84":"2022-07-17T08:19:59.640Z","85":"2022-07-15T01:19:07.000Z","86":"2022-07-14T19:30:34.210Z","87":"2022-07-14T18:54:03.220Z","88":"2022-07-13T16:01:36.530Z","89":"2022-07-08T10:29:52.960Z","90":"2022-07-07T01:30:31.400Z","91":"2022-07-06T06:15:46.400Z","92":"2022-07-05T02:42:05.220Z","93":"2022-07-04T07:22:41.360Z","94":"2022-07-01T05:27:56.810Z","95":"2022-06-29T04:19:36.690Z","96":"2022-06-28T11:57:40.710Z","98":"2022-06-24T09:05:12.080Z","99":"2022-06-18T20:14:16.080Z","100":"2022-06-17T23:47:52.230Z","101":"2022-06-16T17:58:34.410Z","102":"2022-06-15T02:18:33.050Z","103":"2022-06-13T09:40:43.530Z","104":"2022-06-09T07:34:17.520Z","105":"2022-06-08T22:48:21.560Z","106":"2022-06-08T14:41:32.920Z","107":"2022-06-03T10:40:29.910Z","108":"2022-06-02T12:07:22.230Z","109":"2022-05-31T23:53:29.030Z","110":"2022-05-28T00:42:05.860Z","111":"2022-05-26T09:23:32.530Z","112":"2022-05-26T08:11:39.700Z","113":"2022-05-22T01:30:30.390Z","114":"2022-05-16T06:16:50.290Z","115":"2022-05-14T21:28:14.790Z","116":"2022-05-13T19:45:18.040Z","117":"2022-05-13T13:32:36.610Z","118":"2022-05-10T06:53:51.020Z","119":"2022-05-09T23:21:37.400Z","120":"2022-05-09T21:35:33.550Z","121":"2022-05-02T21:56:48.810Z","122":"2022-05-01T03:17:37.970Z","123":"2022-04-30T18:17:56.920Z","124":"2022-04-22T05:02:34.900Z","125":"2022-04-21T18:58:50.260Z","126": ...
